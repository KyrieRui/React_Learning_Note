# %% [markdown]
# ## React Study Note
# ### 11/09/2022
#
# ### If and else statement using in React
# ###
# ```React
#   function coinToss () {
#     // Randomly return either 'heads' or 'tails'.
#     return Math.random() < 0.5 ? 'heads' : 'tails';
#   }
#
#   const pics = {
#     kitty: 'https://content.codecademy.com/courses/React/react_photo-kitty.jpg',
#     doggy: 'https://content.codecademy.com/courses/React/react_photo-puppy.jpeg'
#   };
#
#   // if/else statement begins here:
#   const img = <img src={pics[coinToss()== 'heads'? 'kitty' : 'doggy']} />;
#
#   ReactDOM.render(
#     img,
#     document.getElementById('app')
#   );
# ```

# %% [markdown]
# ###  "true statement && the thing u wana do if true"
#
# ```React
#     import React from 'react';
#     import ReactDOM from 'react-dom';
#
#     // judgmental will be true half the time.
#     const judgmental = Math.random() < 0.5;
#
#     const favoriteFoods = (
#     <div>
#         <h1>My Favorite Foods</h1>
#         <ul>
#         <li>Sushi Burrito</li>
#         <li>Rhubarb Pie</li>
#
#         // if judgmental is true, include the <li> below
#         { !judgmental && <li>Nacho Cheez Straight Out The Jar</li>}
#         <li>Broiled Grapefruit</li>
#         </ul>
#     </div>
#     );
#
#     ReactDOM.render(
#         favoriteFoods,
#         document.getElementById('app')
#     );
# ```

# %% [markdown]
# ## Map also can use in React
# ### We create a array list, then: "const def_name = array_name.map(elements_name => <tag>{elements_name}</tag>"
# ```React
#     import React from 'react';
#     import ReactDOM from 'react-dom';
#
#     const people = ['Rowe', 'Prevost', 'Gare'];
#
#     const peopleLis = people.map(person =>
#     // expression goes here: * the "{}" must be used to return the value
#     <li>{person}</li>
#     );
#
#     // ReactDOM.render goes here: * same here
#     ReactDOM.render(<ul>{peopleLis}</ul>,document.getElementById('app'))
# ```

# %% [markdown]
# ## Key in React
#
# ```React
#     <ul>
#         <li key="li-01">Example1</li>
#         <li key="li-02">Example2</li>
#         <li key="li-03">Example3</li>
#     </ul>
#
#     const peopleLIs = people.map((person, i) =>
#
#     key={'person_' + i}
#
# ```
#
# ### first def a elements 'peopleLIs', then give the  ".map" a random num 'i'
# ### second, bind key with elements and i, * remember to use "{}" to return the value
# ```React
#     import React from 'react';
#     import ReactDOM from 'react-dom';
#
#     const people = ['Rowe', 'Prevost', 'Gare'];
#
#     const peopleLis = people.map((person, i) =>
#     // expression goes here:
#     <li key={"person_" + i}>{person}</li>
#     );
#
#     // ReactDOM.render goes here:
#     ReactDOM.render(<ul>{peopleLis}</ul>,document.getElementById('app'))
# ```

# %% [markdown]
# ## React.createElement
# ### with out JSX we can use"React.createElement()" to define the element like that
# ```React
#     const h1 = <h1>Hello world</h1>;
#
#     const h1 = React.createElement(
#         "h1",
#         null,
#         "Hello world"
#     );
# ```

# %% [markdown]
# ## 12/09/2022
# ### JSX in a Component
#
# ```React
#     import React from 'react';
#     import ReactDOM from 'react-dom';
#
#     //def a class first and extends to "React.Component"
#     class QuoteMaker extends React.Component {
#
#     //add a render function
#     render() {
#         return (//flow with the JSX code
#             <blockquote>
#             <p>
#                 What is important now is to recover our senses.
#             </p>
#             <cite>
#                 <a target="_blank"
#                 href="https://en.wikipedia.org/wiki/Susan_Sontag">
#                 Susan Sontag
#                 </a>
#             </cite>
#             </blockquote>
#         );
#         }
#     };
#
#     //at last use "ReactDOM.render" to render the component
#     ReactDOM.render(
#     <QuoteMaker />,
#     document.getElementById('app')
#     )
# ```

# %% [markdown]
# ### Use a Variable Attribute in a Component
#
# ```React
#     import React from 'react';
#     import ReactDOM from 'react-dom';
#
#     //def an element first
#     const owl = {
#         title: 'Excellent Owl',
#         src: 'https://content.codecademy.com/courses/React/react_photo-owl.jpg'
#     };
#
#     // Component class starts here:
#     class Owl extends React.Component {
#         render(){
#             return(
#             <div>
#                 <h1>{owl.title}</h1>
#                 <img
#                 src={owl.src}
#                 alt={owl.title} />
#             </div>
#             );
#         }
#     };
#
#     ReactDOM.render(
#         <Owl />,
#         document.getElementById('app')
#     );
# ```

# %% [markdown]
# ## Put Logic in a Render Function
#
# ```React
#     import React from 'react';
#     import ReactDOM from 'react-dom';
#
#     const friends = [
#     {
#         title: "Yummmmmmm",
#         src: "https://content.codecademy.com/courses/React/react_photo-monkeyweirdo.jpg"
#     },
#     {
#         title: "Hey Guys!  Wait Up!",
#         src: "https://content.codecademy.com/courses/React/react_photo-earnestfrog.jpg"
#     },
#     {
#         title: "Yikes",
#         src: "https://content.codecademy.com/courses/React/react_photo-alpaca.jpg"
#     }
#     ];
#
#     // New component class starts here:
#     class Friend extends React.Component {
#     render(){
#         const friend = friends[0]
#         return(
#         <div>
#             <h1>{friend.title}</h1>
#             <img src={friend.src} />
#         </div>
#         );
#     }
#     };
#
#     ReactDOM.render(
#     <Friend />,
#     document.getElementById('app')
#     );
# ```

# %% [markdown]
# ## Use a Conditional in a Render Function
# ```React
#     import React from 'react';
#     import ReactDOM from 'react-dom';
#
#     const fiftyFifty = Math.random() < 0.5;
#
#     // New component class starts here: *For loop using should return
#     class TonightsPlan extends React.Component{
#     render(){
#         let task;
#         if (!fiftyFifty) {
#         return (<h1>Tonight I'm going out WOOO</h1>);
#         } else {
#         return(<h1>Tonight I'm going to bed WOOO</h1>);
#         }
#     }
#     };
#
#     ReactDOM.render(
#         <TonightsPlan />,
#         document.getElementById('app')
#     );
# ```

# %% [markdown]
# ###  Use "this" in a Component
# ```React
#     import React from 'react';
#     import ReactDOM from 'react-dom';
#
#     class MyName extends React.Component {
#         // name property goes here:
#         get name() {
#             return 'whatever-your-name-is-goes-here';
#         }
#
#         render() {
#             return <h1>My name is {this.name}.</h1>;
#         }
#     }
#
#     ReactDOM.render(<MyName />, document.getElementById('app'));
# ```

# %% [markdown]
# ### Event in React!
# ```React
#     import React from 'react';
#     import ReactDOM from 'react-dom';
#
#     class Button extends React.Component {
#     scream() {
#         alert('AAAAAAAAHHH!!!!!');
#     }
#
#     render() {
#         return <button onClick = {this.scream}>AAAAAH!</button>;
#     }
#     }
#
#     ReactDOM.render(<Button />, document.getElementById('app'));
# ```

# %% [markdown]
# ## 14/09/2022
#
# ### Access a Component's props
#
# ```React
#
#     import React from 'react';
#     import ReactDOM from 'react-dom';
#
#     class PropsDisplayer extends React.Component {
#     render() {
#         const stringProps = JSON.stringify(this.props);
#
#         return (
#         <div>
#             <h1>CHECK OUT MY PROPS OBJECT</h1>
#             //add element: {stringProps}
#             <h2>{stringProps}</h2>
#         </div>
#         );
#     }
#     }
#
#     // ReactDOM.render goes here:
#     ReactDOM.render(<PropsDisplayer />, document.getElementById('app'))
# ```

# %% [markdown]
# ### Pass `props` to a Component
#
# ```React
#     import React from 'react';
#     import ReactDOM from 'react-dom';
#
#     class PropsDisplayer extends React.Component {
#     render() {
#         const stringProps = JSON.stringify(this.props);
#
#         return (
#         <div>
#             <h1>CHECK OUT MY PROPS OBJECT</h1>
#             <h2>{stringProps}</h2>
#         </div>
#         );
#     }
#     }
#
#     // ReactDOM.render goes here: *pass props to the component
#     ReactDOM.render(<PropsDisplayer myProp="Hello"/>, document.getElementById('app'))
# ```

# %% [markdown]
# ### Render a Component's props
# ```React
#     import React from 'react';
#     import ReactDOM from 'react-dom';
#
#     class Greeting extends React.Component {
#     render() { // improt the {this.props.firstName}
#         return <h1>Hi there, {this.props.firstName}!</h1>;
#     }
#     }
#
#     ReactDOM.render(
#         // and u can change the string that u want display anytime here
#     <Greeting firstName='Ray' />,
#     document.getElementById('app')
#     );
# ```

# %% [markdown]
# ### Pass props From Component To Component
#
# ### when we pass a props from one class to other
# #### first, "export class..." in first class
# #### second, "import {first_class_name} from './path'" in second class top
# #### third, in second class render, use "<first_class_name + name="what ever string u want to put">"
# ```React
#     import React from 'react';
#
#     export class Greeting extends React.Component {
#         render() {
#             return <h1>Hi there, {this.props.name}!</h1>;
#         }
#     }
#
# ```
#
# ```React
#     import React from 'react';
#     import ReactDOM from 'react-dom';
#     import {Greeting} from './Greeting'
#
#     class App extends React.Component {
#         render() {
#             return (
#             <div>
#                 <h1>
#                 Hullo and, "Welcome to The Newzz," "On Line!"
#                 </h1>
#                 <Greeting name="Ray"/>
#                 <article>
#                 Latest newzz:  where is my phone?
#                 </article>
#             </div>
#             );
#         }
#     }
#
#     ReactDOM.render(
#         <App />,
#         document.getElementById('app')
#     );
# ```

# %% [markdown]
# ### Render Different UI Based on props
#
# ```React
#     import React from 'react';
#     import ReactDOM from 'react-dom';
#     import { Greeting } from './Greeting';
#
#     class App extends React.Component {
#         render() {
#             return (
#             <div>
#                 <h1>
#                 Hullo and, "Welcome to The Newzz," "On Line!"
#                 </h1>
#                 <Greeting name="Alison"
#                         signedIn={true} />
#                 <article>
#                 Latest:  where is my phone?
#                 </article>
#             </div>
#             );
#         }
#     }
#
#     ReactDOM.render(
#         <App />,
#         document.getElementById('app')
#     );
# ```
#
# ```React
#     import React from 'react';
#     import ReactDOM from 'react-dom';
#
#     export class Greeting extends React.Component {
#         render() {
#             if (this.props.signedIn === false) {
#             return <h1>GO AWAY</h1>;
#             } else {
#             return <h1>Hi there, {this.props.name}!</h1>;
#             }
#         }
#     }
# ```

# %% [markdown]
# ### Put an Event Handler in a Component Class
# #### combine the fuc in class
# ```React
#     import React from 'react';
#     import ReactDOM from 'react-dom';
#     import { Button } from './Button';
#
#     class Talker extends React.Component {
#     talk(){
#         let speech = '';
#         for (let i = 0; i < 10000; i++) {
#             speech+='bla'
#         }
#         alert(speech)
#     }
#         render() {
#             return <Button />;
#         }
#     }
#
#     ReactDOM.render(
#         <Talker />,
#         document.getElementById('app')
#     );
# ```

# %% [markdown]
# ### Pass an Event Handler as a prop
# ```React
# import React from 'react';
# import ReactDOM from 'react-dom';
# import { Button } from './Button';
#
# class Talker extends React.Component {
#   talk() {
#     let speech = '';
#     for (let i = 0; i < 10000; i++) {
#       speech += 'blah ';
#     }
#     alert(speech);
#   }
#
#   render() {
#     // give Button a name with ur func, and the value {this.fuc_name}
#     return <Button talk={this.talk}/>;
#   }
# }
#
# ReactDOM.render(
#   <Talker />,
#   document.getElementById('app')
# );
# ```

# %% [markdown]
# ## give Button an event: onClick={this.props.talk}
#
# ```React
# import React from 'react';
#
# export class Button extends React.Component {
#   render() {
#     return (
#       <button onClick={this.props.talk}>
#         Click me!
#       </button>
#     );
#   }
# }
# ```

# %% [markdown]
# ### this.props.children
#
# ```React
# import React from 'react';
#
# export class List extends React.Component {
#   render() {
#     let titleText = `Favorite ${this.props.type}`;
#     if (this.props.children instanceof Array) {
#     	titleText += 's';
#     }
#     return (
#       <div>
#         <h1>{titleText}</h1>
#         //give the value of{this.props.children} to ul, which will return the li childern
#         <ul>{this.props.children}</ul>
#       </div>
#     );
#   }
# }
# ```
#
# ```React
# import React from 'react';
# import ReactDOM from 'react-dom';
# import { List } from './List';
#
# class App extends React.Component {
#   render() {
#     return (
#       <div>
#         <List type='Living Musician'>
#           <li>Sachiko M</li>
#           <li>Harvey Sid Fisher</li>
#         </List>
#         <List type='Living Cat Musician'>
#           <li>Nora the Piano Cat</li>
#         </List>
#       </div>
#     );
#   }
# }
#
# ReactDOM.render(
#   <App />,
#   document.getElementById('app')
# );
# ```

# %% [markdown]
# ### defaultProps
#
# ```React
# import React from 'react';
# import ReactDOM from 'react-dom';
#
# class Button extends React.Component {
#   render() {
#     return (
#       <button>
#         {this.props.text}
#       </button>
#     );
#   }
# }
#
# // defaultProps goes here: override the default value
# Button.defaultProps={ text: 'I am a button' }
#
#
# ReactDOM.render(
#     //for this text u can design again, if u dont have this text=..., the display will be defalt... on the top
#   <Button text="Ray"/>,
#   document.getElementById('app')
# );
# ```
